# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# >> Visualization
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
from scipy.stats import chi2_contingency
from IPython.display import display
from itertools import combinations
from scipy.stats import kstest, spearmanr, pearsonr
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("spain.csv", index_col=0)
data.head()
# Out:
#             restaurant_link       restaurant_name  \
# 320900  g10021880-d13763192  Taberna La Sacristia
# 320901  g10021880-d15758746     Tasca el Capricho
# 320902  g10021880-d19332558       Bar Las Adelfas
# 320903  g10021880-d19468788        El Rincon nº 7
# 320904  g10021880-d19847377       Nuevo jacaranda
#
#                                         original_location country     region  \
# 320900  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320901  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320902  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320903  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320904  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
#
#                    province city  \
# 320900  Province of Seville  NaN
# 320901  Province of Seville  NaN
# 320902  Province of Seville  NaN
# 320903  Province of Seville  NaN
# 320904  Province of Seville  NaN
#
#                                                   address  latitude  \
# 320900      Calle del Concejo 19, 41870 Aznalcollar Spain  37.51928
# 320901  Calle del 28 de Febrero 9, 41870 Aznalcollar S...  37.52065
# 320902  Calle Perdon N° 23 Capilla de La Cruz, 41870 A...  37.52428
# 320903      Calle del Concejo 60, 41870 Aznalcollar Spain  37.51714
# 320904  Calle del 28 de Febrero 2, 41870 Aznalcollar S...  37.52088
#
#         longitude    claimed awards                 popularity_detailed  \
# 320900   -6.26885  Unclaimed    NaN  #4 of 5 Restaurants in Aznalcollar
# 320901   -6.26822  Unclaimed    NaN  #3 of 5 Restaurants in Aznalcollar
# 320902   -6.27144    Claimed    NaN  #5 of 5 Restaurants in Aznalcollar
# 320903   -6.26860    Claimed    NaN  #1 of 5 Restaurants in Aznalcollar
# 320904   -6.26844    Claimed    NaN                                 NaN
#
#                           popularity_generic  \
# 320900  #4 of 6 places to eat in Aznalcollar
# 320901  #3 of 6 places to eat in Aznalcollar
# 320902  #5 of 6 places to eat in Aznalcollar
# 320903  #1 of 6 places to eat in Aznalcollar
# 320904                                   NaN
#
#                                     top_tags price_level price_range  \
# 320900                               Spanish         NaN         NaN
# 320901                               Spanish         NaN         NaN
# 320902  Mediterranean, Spanish, Grill, Diner         NaN         NaN
# 320903  Mid-range, Steakhouse, Cafe, Spanish      €€-€€€      €2-€18
# 320904                                   NaN         NaN         NaN
#
#                                            meals  \
# 320900                                       NaN
# 320901                                       NaN
# 320902  Breakfast, Lunch, Dinner, Brunch, Drinks
# 320903                     Lunch, Dinner, Drinks
# 320904                                       NaN
#
#                                                  cuisines special_diets  \
# 320900                                            Spanish           NaN
# 320901                                            Spanish           NaN
# 320902  Mediterranean, Spanish, Grill, Diner, Dining bars           NaN
# 320903             Steakhouse, Cafe, Dining bars, Spanish           NaN
# 320904                                                NaN           NaN
#
#             features vegetarian_friendly vegan_options gluten_free  \
# 320900           NaN                   N             N           N
# 320901           NaN                   N             N           N
# 320902           NaN                   N             N           N
# 320903           NaN                   N             N           N
# 320904  Reservations                   N             N           N
#
#                                       original_open_hours  open_days_per_week  \
# 320900                                                NaN                 NaN
# 320901                                                NaN                 NaN
# 320902  {"Mon": [], "Tue": ["19:30-23:45"], "Wed": ["1...                 6.0
# 320903  {"Mon": [], "Tue": [], "Wed": [], "Thu": ["20:...                 4.0
# 320904                                                NaN                 NaN
#
#         open_hours_per_week  working_shifts_per_week  avg_rating  \
# 320900                  NaN                      NaN         3.0
# 320901                  NaN                      NaN         5.0
# 320902                 51.0                      6.0         3.0
# 320903                 23.0                      7.0         5.0
# 320904                  NaN                      NaN         NaN
#
#         total_reviews_count default_language  \
# 320900                  1.0          English
# 320901                  2.0    All languages
# 320902                  2.0    All languages
# 320903                 18.0    All languages
# 320904                  NaN              NaN
#
#         reviews_count_in_default_language  excellent  very_good  average  \
# 320900                                1.0        0.0        0.0      1.0
# 320901                                2.0        2.0        0.0      0.0
# 320902                                2.0        1.0        0.0      0.0
# 320903                               18.0       17.0        1.0      0.0
# 320904                                NaN        NaN        NaN      NaN
#
#         poor  terrible  food  service  value  atmosphere keywords
# 320900   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320901   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320902   0.0       1.0   NaN      NaN    NaN         NaN      NaN
# 320903   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320904   NaN       NaN   NaN      NaN    NaN         NaN      NaN

# %%
def change_null_cuisine(df,column_list): # rellena con spanish (categoria dominante) para variable CUISINE.
     
        for column in column_list:
            if column in df.columns:

                df[column] = df[column].fillna("Spanish")
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df

def change_null_for_standar_number(df, column_list): # rellena con -1 las columnas numéricas para los nulos.
     
        for column in column_list:
            if column in df.columns:

                df[column] = df[column].fillna(-1)
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df

def change_null_for_unknown(df,column_list): # Cuando no existe una categoría dominante en una variable categórica
     
        for column in column_list:
            if column in df.columns:

                df[column] = df[column].fillna("Unknown")
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df
    
def change_null_for_mode(df,column_list): # Cuando hay una categoría dominante en variables categóricas
        for column in column_list:
            if column in df.columns:
                mode = df[column].mode()[0]
          
                df[column] = df[column].fillna(mode)
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df
    
def change_null_for_mean(df, column_list):  # Cuando tenemos un 0-10% de nulos en una categoría numérica y la distribución es normal
        for column in column_list:
            if column in df.columns:
                    mean= df[column].mean()
              
                    df[column] = df[column].fillna(mean)
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df
    
def change_null_for_median(df, column_list):  # Cuando tenemos un 0-10% de nulos en una categoría numérica y la distribución es atípica
        for column in column_list:
            if column in df.columns:
                    median= df[column].median()
                
                    df[column] = df[column].fillna(median)
            else:
                print(f"Warning: The column '{column}' does not exist in the DataFrame.")
        return df

def impute_with_knn(df, column_list, n_neighbors=5): # Cuando tenemos variables numéricas con más 10% de nulos
   
        imputer_knn = KNNImputer(n_neighbors=n_neighbors)

        imputed_data = imputer_knn.fit_transform(df[column_list])

        imputed_df = pd.DataFrame(imputed_data, columns=column_list)

        for column in column_list:
            df[f"{column}_knn"] = imputed_df[column]

        return df

def transform_to_integer(df, column_name):
        """Transform floats to int"""
        df[column_name] = df[column_name].astype(int)

def drop_redundant_columns(df, columns):
        """Drops redundant columns . Param columns is a list of columns to de dropped"""
        df.drop(columns=columns, inplace=True, errors='ignore')


def map_column_yes_or_no(df, column):
    dicc = {"N": "No", "Y": "Yes"}

    # Reemplaza valores con los del diccionario para la columna que metamos en el atributo.
    df[column] =df[column].map(dicc)

def quick_check(df,column_name):
        """ This function is for testing purposes, to quicky check data type and unique values of a column"""
        print (f"Column name: {column_name}")
        print (f"Data type: {df[column_name].dtype}")
        print (f"Unique values: {df[column_name].unique()}")
        print (f"Null count: {df[column_name].isnull().sum()}")

def convert_price_range(df):
        # Primero reemplazados el concepto €€- €€€ para €€
        df["price_level"] =df["price_level"].replace({"€€-€€€": "€€"})
      
        
        conversion_dictionary = {
        "€": "0 - 20€",
        "€€" : "20 - 50€",
        "€€€" : "50 - 80€", # no hay en el listado estos valores que hacemos??? los nulos los modificamos aqui?
        "€€€€" : "más de 80€"
         }

        # Aplicar la conversión usando .map() para reemplazar todos los valores de la columna
        df["price_range"] = df["price_level"].map(conversion_dictionary)

# %% [markdown]
# # COMPROBACIONES

# %%
columns_modify = ["", ""]
change_null_for_mean(data, columns_modify)

# print for tasting
for column in columns_modify:
    quick_check(data, column)
    print("----------------------------------------------")
# Out:
# Warning: The column '' does not exist in the DataFrame.
# Warning: The column '' does not exist in the DataFrame.
# Column name:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [4], in <cell line: 5>()
#       4 # print for tasting
#       5 for column in columns_modify:
# ----> 6     quick_check(data, column)
#       7     print("----------------------------------------------")
#
# Input In [3], in quick_check(df, column_name)
#      90 """ This function is for testing purposes, to quicky check data type and unique values of a column"""
#      91 print (f"Column name: {column_name}")
# ---> 92 print (f"Data type: {df[column_name].dtype}")
#      93 print (f"Unique values: {df[column_name].unique()}")
#      94 print (f"Null count: {df[column_name].isnull().sum()}")
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ''

# %%
map_column_yes_or_no(data,"vegetarian_friendly")

# %%
data["vegetarian_friendly"].value_counts()
# Out:
# vegetarian_friendly
# No     119740
# Yes     37739
# Name: count, dtype: int64

# %%
convert_price_range(data)

# %%
print(data["price_level"].unique())
# Out:
# [nan '€€' '€' '€€€€']

# %%
data["price_level"].value_counts()
# Out:
# price_level
# €€      79406
# €       33489
# €€€€     3913
# Name: count, dtype: int64

# %%
data["price_range"].value_counts()
# Out:
# price_range
# 20 - 50€      79406
# 0 - 20€       33489
# más de 80€     3913
# Name: count, dtype: int64

# %%
data.head()
# Out:
#             restaurant_link       restaurant_name  \
# 320900  g10021880-d13763192  Taberna La Sacristia
# 320901  g10021880-d15758746     Tasca el Capricho
# 320902  g10021880-d19332558       Bar Las Adelfas
# 320903  g10021880-d19468788        El Rincon nº 7
# 320904  g10021880-d19847377       Nuevo jacaranda
#
#                                         original_location country     region  \
# 320900  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320901  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320902  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320903  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
# 320904  ["Europe", "Spain", "Andalucia", "Province of ...   Spain  Andalucia
#
#                    province city  \
# 320900  Province of Seville  NaN
# 320901  Province of Seville  NaN
# 320902  Province of Seville  NaN
# 320903  Province of Seville  NaN
# 320904  Province of Seville  NaN
#
#                                                   address  latitude  \
# 320900      Calle del Concejo 19, 41870 Aznalcollar Spain  37.51928
# 320901  Calle del 28 de Febrero 9, 41870 Aznalcollar S...  37.52065
# 320902  Calle Perdon N° 23 Capilla de La Cruz, 41870 A...  37.52428
# 320903      Calle del Concejo 60, 41870 Aznalcollar Spain  37.51714
# 320904  Calle del 28 de Febrero 2, 41870 Aznalcollar S...  37.52088
#
#         longitude    claimed awards                 popularity_detailed  \
# 320900   -6.26885  Unclaimed    NaN  #4 of 5 Restaurants in Aznalcollar
# 320901   -6.26822  Unclaimed    NaN  #3 of 5 Restaurants in Aznalcollar
# 320902   -6.27144    Claimed    NaN  #5 of 5 Restaurants in Aznalcollar
# 320903   -6.26860    Claimed    NaN  #1 of 5 Restaurants in Aznalcollar
# 320904   -6.26844    Claimed    NaN                                 NaN
#
#                           popularity_generic  \
# 320900  #4 of 6 places to eat in Aznalcollar
# 320901  #3 of 6 places to eat in Aznalcollar
# 320902  #5 of 6 places to eat in Aznalcollar
# 320903  #1 of 6 places to eat in Aznalcollar
# 320904                                   NaN
#
#                                     top_tags price_level price_range  \
# 320900                               Spanish         NaN         NaN
# 320901                               Spanish         NaN         NaN
# 320902  Mediterranean, Spanish, Grill, Diner         NaN         NaN
# 320903  Mid-range, Steakhouse, Cafe, Spanish      €€-€€€      €2-€18
# 320904                                   NaN         NaN         NaN
#
#                                            meals  \
# 320900                                       NaN
# 320901                                       NaN
# 320902  Breakfast, Lunch, Dinner, Brunch, Drinks
# 320903                     Lunch, Dinner, Drinks
# 320904                                       NaN
#
#                                                  cuisines special_diets  \
# 320900                                            Spanish           NaN
# 320901                                            Spanish           NaN
# 320902  Mediterranean, Spanish, Grill, Diner, Dining bars           NaN
# 320903             Steakhouse, Cafe, Dining bars, Spanish           NaN
# 320904                                                NaN           NaN
#
#             features vegetarian_friendly vegan_options gluten_free  \
# 320900           NaN                   N             N           N
# 320901           NaN                   N             N           N
# 320902           NaN                   N             N           N
# 320903           NaN                   N             N           N
# 320904  Reservations                   N             N           N
#
#                                       original_open_hours  open_days_per_week  \
# 320900                                                NaN                 NaN
# 320901                                                NaN                 NaN
# 320902  {"Mon": [], "Tue": ["19:30-23:45"], "Wed": ["1...                 6.0
# 320903  {"Mon": [], "Tue": [], "Wed": [], "Thu": ["20:...                 4.0
# 320904                                                NaN                 NaN
#
#         open_hours_per_week  working_shifts_per_week  avg_rating  \
# 320900                  NaN                      NaN         3.0
# 320901                  NaN                      NaN         5.0
# 320902                 51.0                      6.0         3.0
# 320903                 23.0                      7.0         5.0
# 320904                  NaN                      NaN         NaN
#
#         total_reviews_count default_language  \
# 320900                  1.0          English
# 320901                  2.0    All languages
# 320902                  2.0    All languages
# 320903                 18.0    All languages
# 320904                  NaN              NaN
#
#         reviews_count_in_default_language  excellent  very_good  average  \
# 320900                                1.0        0.0        0.0      1.0
# 320901                                2.0        2.0        0.0      0.0
# 320902                                2.0        1.0        0.0      0.0
# 320903                               18.0       17.0        1.0      0.0
# 320904                                NaN        NaN        NaN      NaN
#
#         poor  terrible  food  service  value  atmosphere keywords
# 320900   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320901   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320902   0.0       1.0   NaN      NaN    NaN         NaN      NaN
# 320903   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 320904   NaN       NaN   NaN      NaN    NaN         NaN      NaN

# %%
df = data.copy() # hace una copia

# %%
df2= df["address"].str.split(pat="(\d{5})(.*)",expand=True)

# %%
df2.sample(5)
# Out:
#                                       0      1                 2     3
# 432520          Calle Juan Trejo, nº7,   11380      Tarifa Spain
# 361022         Carretera Cadiz Km 189,   29604  , Marbella Spain
# 388705       Carrer de Villarroel 183,   08036   Barcelona Spain
# 402248    Avenida de Concha Espina 55,   28016      Madrid Spain
# 448991  Vicente Monux 2, Siguenza Spain   None              None  None

# %%
df3 = df2[1].str.split(pat="(\d{5})(.*)",expand=True)

# %%
df4 = df3[2].str.replace("Spain","").reset_index()

# %%
df4.head()
# Out:
#     index              2
# 0  320900   Aznalcollar
# 1  320901   Aznalcollar
# 2  320902   Aznalcollar
# 3  320903   Aznalcollar
# 4  320904   Aznalcollar

# %%
import re
# Función para dividir la dirección en dos partes por el código postal
def extraer_direccion(direccion):
    # Buscar "Spain" en la dirección y cortar hasta ese punto
    if "Spain" in direccion:
        direccion = direccion.split("Spain")[0].strip()
    
    # Usar regex para encontrar la parte antes de una coma o un dígito
    match = re.search(r'^[^,\d]+', direccion)
    if match:
        return match.group(0).strip()
    else:
        return direccion.strip()

df[['direccion_filtrada']] = df['address'].apply(extraer_direccion).apply(pd.Series)

# %%
df.sample(5)
# Out:
#            restaurant_link       restaurant_name  \
# 324267  g1052753-d10083765         El Pintoresco
# 388333   g187497-d15276653               Olofson
# 343426    g187529-d4188372      California Stars
# 381276     g187484-d942347              La Radio
# 417182    g187527-d6591656  Rincon de Las Jarras
#
#                                         original_location country  \
# 324267  ["Europe", "Spain", "Canary Islands", "Tenerif...   Spain
# 388333  ["Europe", "Spain", "Catalonia", "Province of ...   Spain
# 343426  ["Europe", "Spain", "Valencian Country", "Prov...   Spain
# 381276      ["Europe", "Spain", "Cantabria", "Santander"]   Spain
# 417182  ["Europe", "Spain", "Valencian Country", "Prov...   Spain
#
#                    region               province          city  \
# 324267     Canary Islands               Tenerife  Las Galletas
# 388333          Catalonia  Province of Barcelona           NaN
# 343426  Valencian Country   Province of Valencia           NaN
# 381276          Cantabria                    NaN     Santander
# 417182  Valencian Country   Province of Alicante           NaN
#
#                                                   address   latitude  \
# 324267  Calle Dionisio Gonzalez s/n Puerto Local 4-1, ...  28.007261
# 388333                  Londres 54, 08036 Barcelona Spain  41.390930
# 343426  Calle San Vicente Martir 207, 46007, Valencia ...  39.457040
# 381276  Avenida del General Davila, 103, 39006 Santand...  43.464516
# 417182       Calle Maria Parodi 3, 03181 Torrevieja Spain  37.976550
#
#         longitude    claimed  \
# 324267 -16.658663    Claimed
# 388333   2.147560    Claimed
# 343426  -0.383490  Unclaimed
# 381276  -3.819149  Unclaimed
# 417182  -0.680364  Unclaimed
#
#                                                    awards  \
# 324267                                                NaN
# 388333                                                NaN
# 343426                                                NaN
# 381276  Certificate of Excellence 2019, Certificate of...
# 417182                                                NaN
#
#                            popularity_detailed  \
# 324267   #29 of 60 Restaurants in Las Galletas
# 388333  #4729 of 8661 Restaurants in Barcelona
# 343426   #3202 of 3413 Restaurants in Valencia
# 381276     #58 of 564 Restaurants in Santander
# 417182   #285 of 583 Restaurants in Torrevieja
#
#                                popularity_generic  \
# 324267    #30 of 68 places to eat in Las Galletas
# 388333  #5265 of 10645 places to eat in Barcelona
# 343426    #3466 of 4238 places to eat in Valencia
# 381276      #63 of 661 places to eat in Santander
# 417182    #295 of 672 places to eat in Torrevieja
#
#                                                  top_tags price_level  \
# 324267                                Cheap Eats, Spanish           €
# 388333                  Mid-range, European, Pub, Healthy      €€-€€€
# 343426                                Mid-range, American      €€-€€€
# 381276         Mid-range, Seafood, Mediterranean, Spanish      €€-€€€
# 417182  Mid-range, Mediterranean, Spanish, Vegetarian ...      €€-€€€
#
#        price_range          meals                         cuisines  \
# 324267      €8-€30  Lunch, Dinner                          Spanish
# 388333         NaN            NaN  Pub, Healthy, Swedish, European
# 343426         NaN         Dinner                         American
# 381276     €18-€24            NaN  Seafood, Mediterranean, Spanish
# 417182         NaN  Lunch, Dinner           Spanish, Mediterranean
#
#               special_diets  \
# 324267                  NaN
# 388333                  NaN
# 343426                  NaN
# 381276  Gluten Free Options
# 417182  Vegetarian Friendly
#
#                                                  features vegetarian_friendly  \
# 324267                                                NaN                   N
# 388333               Reservations, Seating, Table Service                   N
# 343426  Seating, Wheelchair Accessible, Table Service,...                   N
# 381276                                                NaN                   N
# 417182                                                NaN                   Y
#
#        vegan_options gluten_free  \
# 324267             N           N
# 388333             N           N
# 343426             N           N
# 381276             N           Y
# 417182             N           N
#
#                                       original_open_hours  open_days_per_week  \
# 324267  {"Mon": ["12:00-00:00"], "Tue": [], "Wed": ["1...                 6.0
# 388333                                                NaN                 NaN
# 343426                                                NaN                 NaN
# 381276  {"Mon": ["12:00-00:00"], "Tue": ["12:00-00:00"...                 7.0
# 417182                                                NaN                 NaN
#
#         open_hours_per_week  working_shifts_per_week  avg_rating  \
# 324267                 72.0                      6.0         4.5
# 388333                  NaN                      NaN         4.0
# 343426                  NaN                      NaN         3.0
# 381276                 76.0                      7.0         4.0
# 417182                  NaN                      NaN         3.5
#
#         total_reviews_count default_language  \
# 324267                 29.0          English
# 388333                 12.0          English
# 343426                 52.0          English
# 381276                906.0          English
# 417182                 59.0          English
#
#         reviews_count_in_default_language  excellent  very_good  average  \
# 324267                                5.0        2.0        2.0      1.0
# 388333                                4.0        4.0        0.0      0.0
# 343426                                4.0        3.0        0.0      0.0
# 381276                               37.0       15.0       18.0      1.0
# 417182                                9.0        2.0        6.0      0.0
#
#         poor  terrible  food  service  value  atmosphere keywords  \
# 324267   0.0       0.0   4.0      4.0    4.5         NaN      NaN
# 388333   0.0       0.0   NaN      NaN    NaN         NaN      NaN
# 343426   1.0       0.0   3.0      3.5    3.0         3.0      NaN
# 381276   1.0       2.0   4.5      3.5    4.0         3.5      NaN
# 417182   1.0       0.0   4.0      4.0    4.0         NaN      NaN
#
#                               direccion_filtrada
# 324267  Calle Dionisio Gonzalez s/n Puerto Local
# 388333                                   Londres
# 343426                  Calle San Vicente Martir
# 381276                Avenida del General Davila
# 417182                        Calle Maria Parodi
